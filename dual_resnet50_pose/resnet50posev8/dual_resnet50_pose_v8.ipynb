# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')

import matplotlib.pyplot as plt

import os
import pandas as pd

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.utils.data as data
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.optim as optim

import torchvision
from torchvision.models import resnet50, ResNet50_Weights
from torchvision.io import read_image
import torchvision.transforms as transforms

from tqdm import tqdm

import time

import PIL
# Out:
# Mounted at /content/drive

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torchinfo

# %%
class CustomRGBImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)[0:9000]
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        label = torch.tensor(self.img_labels.iloc[idx, 1:7])
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label


class CustomDepthImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)[0:9000]
        for index, img_label in enumerate(self.img_labels.iloc[:,0]):
            depth_img_label = img_label.replace("rgb_image_", "depth_image_").replace("png", "npy")
            self.img_labels.iloc[index,0] = depth_img_label

        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        np_img = np.load(img_path)
        np_img[np_img > 1] = 0
        np_img[np.isnan(np_img)] = 0
        image = torch.tensor(np_img).unsqueeze(0)
        image = image.expand(3, *image.shape[1:])
        label = torch.tensor(self.img_labels.iloc[idx, 1:7])
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label






depth_transform  = torchvision.transforms.Compose([
    torchvision.transforms.Grayscale(num_output_channels=3),
    torchvision.transforms.Resize((224,224)),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.25, 0.25, 0.25)),
    #torchvision.transforms.ToTensor(),
])


rgb_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224,224)),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.25, 0.25, 0.25)),

])

#print(os.path.exists("drive/MyDrive/Colab Notebooks/dataset_20k/dataset/labels.csv"))

path_to_labels = "drive/MyDrive/Colab Notebooks/dataset_resnet50_augment-10k/labels.csv"
path_to_rgb_imgs = "drive/MyDrive/Colab Notebooks/dataset_resnet50_augment-10k/rgb/"
path_to_depth_imgs = "drive/MyDrive/Colab Notebooks/dataset_resnet50_augment-10k/depth/"


dataset_rgb = CustomRGBImageDataset(path_to_labels, path_to_rgb_imgs)
dataset_depth = CustomDepthImageDataset(path_to_labels, path_to_depth_imgs, transform = depth_transform)


#generator1 = torch.Generator().manual_seed(42)

#[rgb_training_data, rgb_test_data] = torch.utils.data.random_split(dataset_rgb, [0.9, 0.1], generator1)
#[depth_training_data, depth_test_data] = torch.utils.data.random_split(dataset_depth, [0.9, 0.1], generator1)



batch_size = 32



rgb_train_dataloader = DataLoader(dataset_rgb, batch_size=batch_size ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)
#rgb_test_dataloader = DataLoader(rgb_test_data, batch_size=batch_size ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)

depth_train_dataloader = DataLoader(dataset_depth, batch_size=batch_size ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)
#depth_test_dataloader = DataLoader(depth_test_data, batch_size=batch_size ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)


plt.imshow(dataset_rgb.__getitem__(3999)[0][2])

# %%
plt.imshow(dataset_depth.__getitem__(3999)[0][2])

print(torch.max(dataset_depth.__getitem__(4)[0]))

#plt.imshow(rgb_training_data.__getitem__(0)[0][0])
#plt.show()
# Out:
# tensor(0.9992, dtype=torch.float64)

# %%
rgb_cnn = resnet50(weights=ResNet50_Weights.DEFAULT)
depth_cnn = resnet50(weights=ResNet50_Weights.DEFAULT)



depth_cnn
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 117MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
rgb_cnn = resnet50(weights=ResNet50_Weights.DEFAULT)
depth_cnn = resnet50(weights=ResNet50_Weights.DEFAULT)


# Freeze layers before layer 4
for param in rgb_cnn.parameters():
    param.requires_grad = False
for param in depth_cnn.parameters():
    param.requires_grad = False


depth_cnn.layer4 = nn.Sequential(
    nn.Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=True),
    #nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True),
    #nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=True),
    nn.ReLU(inplace=True)
)

rgb_cnn.layer4 = nn.Sequential(
    nn.Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=True),
    #nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True),
    #nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=True),
    nn.ReLU(inplace=True)
)

depth_cnn.fc = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(2048,64,bias=True),
    nn.Tanh()
)

rgb_cnn.fc = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(2048,64,bias=True),
    nn.Tanh()
)

final_pose_estimator = nn.Sequential(
    nn.Linear(128, 6, bias=True)
)


depth_cnn.to('cuda')
rgb_cnn.to('cuda')
final_pose_estimator.to('cuda')

def paralle_cnn(rgb, depth):
    rgb_out = rgb_cnn(rgb)
    depth_out = rgb_cnn(depth)
    cat_out = torch.cat([rgb_out, depth_out], dim=1)
    return final_pose_estimator(cat_out)

torchinfo.summary(depth_cnn)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            (9,408)
# ├─BatchNorm2d: 1-2                       (128)
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─Bottleneck: 2-1                   --
# │    │    └─Conv2d: 3-1                  (4,096)
# │    │    └─BatchNorm2d: 3-2             (128)
# │    │    └─Conv2d: 3-3                  (36,864)
# │    │    └─BatchNorm2d: 3-4             (128)
# │    │    └─Conv2d: 3-5                  (16,384)
# │    │    └─BatchNorm2d: 3-6             (512)
# │    │    └─ReLU: 3-7                    --
# │    │    └─Sequential: 3-8              (16,896)
# │    └─Bottleneck: 2-2                   --
# │    │    └─Conv2d: 3-9                  (16,384)
# │    │    └─BatchNorm2d: 3-10            (128)
# │    │    └─Conv2d: 3-11                 (36,864)
# │    │    └─BatchNorm2d: 3-12            (128)
# │    │    └─Conv2d: 3-13                 (16,384)
# │    │    └─BatchNorm2d: 3-14            (512)
# │    │    └─ReLU: 3-15                   --
# │    └─Bottleneck: 2-3                   --
# │    │    └─Conv2d: 3-16                 (16,384)
# │    │    └─BatchNorm2d: 3-17            (128)
# │    │    └─Conv2d: 3-18                 (36,864)
# │    │    └─BatchNorm2d: 3-19            (128)
# │    │    └─Conv2d: 3-20                 (16,384)
# │    │    └─BatchNorm2d: 3-21            (512)
# │    │    └─ReLU: 3-22                   --
# ├─Sequential: 1-6                        --
# │    └─Bottleneck: 2-4                   --
# │    │    └─Conv2d: 3-23                 (32,768)
# │    │    └─BatchNorm2d: 3-24            (256)
# │    │    └─Conv2d: 3-25                 (147,456)
# │    │    └─BatchNorm2d: 3-26            (256)
# │    │    └─Conv2d: 3-27                 (65,536)
# │    │    └─BatchNorm2d: 3-28            (1,024)
# │    │    └─ReLU: 3-29                   --
# │    │    └─Sequential: 3-30             (132,096)
# │    └─Bottleneck: 2-5                   --
# │    │    └─Conv2d: 3-31                 (65,536)
# │    │    └─BatchNorm2d: 3-32            (256)
# │    │    └─Conv2d: 3-33                 (147,456)
# │    │    └─BatchNorm2d: 3-34            (256)
# │    │    └─Conv2d: 3-35                 (65,536)
# │    │    └─BatchNorm2d: 3-36            (1,024)
# │    │    └─ReLU: 3-37                   --
# │    └─Bottleneck: 2-6                   --
# │    │    └─Conv2d: 3-38                 (65,536)
# │    │    └─BatchNorm2d: 3-39            (256)
# │    │    └─Conv2d: 3-40                 (147,456)
# │    │    └─BatchNorm2d: 3-41            (256)
# │    │    └─Conv2d: 3-42                 (65,536)
# │    │    └─BatchNorm2d: 3-43            (1,024)
# │    │    └─ReLU: 3-44                   --
# │    └─Bottleneck: 2-7                   --
# │    │    └─Conv2d: 3-45                 (65,536)
# │    │    └─BatchNorm2d: 3-46            (256)
# │    │    └─Conv2d: 3-47                 (147,456)
# │    │    └─BatchNorm2d: 3-48            (256)
# │    │    └─Conv2d: 3-49                 (65,536)
# │    │    └─BatchNorm2d: 3-50            (1,024)
# │    │    └─ReLU: 3-51                   --
# ├─Sequential: 1-7                        --
# │    └─Bottleneck: 2-8                   --
# │    │    └─Conv2d: 3-52                 (131,072)
# │    │    └─BatchNorm2d: 3-53            (512)
# │    │    └─Conv2d: 3-54                 (589,824)
# │    │    └─BatchNorm2d: 3-55            (512)
# │    │    └─Conv2d: 3-56                 (262,144)
# │    │    └─BatchNorm2d: 3-57            (2,048)
# │    │    └─ReLU: 3-58                   --
# │    │    └─Sequential: 3-59             (526,336)
# │    └─Bottleneck: 2-9                   --
# │    │    └─Conv2d: 3-60                 (262,144)
# │    │    └─BatchNorm2d: 3-61            (512)
# │    │    └─Conv2d: 3-62                 (589,824)
# │    │    └─BatchNorm2d: 3-63            (512)
# │    │    └─Conv2d: 3-64                 (262,144)
# │    │    └─BatchNorm2d: 3-65            (2,048)
# │    │    └─ReLU: 3-66                   --
# │    └─Bottleneck: 2-10                  --
# │    │    └─Conv2d: 3-67                 (262,144)
# │    │    └─BatchNorm2d: 3-68            (512)
# │    │    └─Conv2d: 3-69                 (589,824)
# │    │    └─BatchNorm2d: 3-70            (512)
# │    │    └─Conv2d: 3-71                 (262,144)
# │    │    └─BatchNorm2d: 3-72            (2,048)
# │    │    └─ReLU: 3-73                   --
# │    └─Bottleneck: 2-11                  --
# │    │    └─Conv2d: 3-74                 (262,144)
# │    │    └─BatchNorm2d: 3-75            (512)
# │    │    └─Conv2d: 3-76                 (589,824)
# │    │    └─BatchNorm2d: 3-77            (512)
# │    │    └─Conv2d: 3-78                 (262,144)
# │    │    └─BatchNorm2d: 3-79            (2,048)
# │    │    └─ReLU: 3-80                   --
# │    └─Bottleneck: 2-12                  --
# │    │    └─Conv2d: 3-81                 (262,144)
# │    │    └─BatchNorm2d: 3-82            (512)
# │    │    └─Conv2d: 3-83                 (589,824)
# │    │    └─BatchNorm2d: 3-84            (512)
# │    │    └─Conv2d: 3-85                 (262,144)
# │    │    └─BatchNorm2d: 3-86            (2,048)
# │    │    └─ReLU: 3-87                   --
# │    └─Bottleneck: 2-13                  --
# │    │    └─Conv2d: 3-88                 (262,144)
# │    │    └─BatchNorm2d: 3-89            (512)
# │    │    └─Conv2d: 3-90                 (589,824)
# │    │    └─BatchNorm2d: 3-91            (512)
# │    │    └─Conv2d: 3-92                 (262,144)
# │    │    └─BatchNorm2d: 3-93            (2,048)
# │    │    └─ReLU: 3-94                   --
# ├─Sequential: 1-8                        --
# │    └─Conv2d: 2-14                      524,800
# │    └─Conv2d: 2-15                      2,359,808
# │    └─Conv2d: 2-16                      1,050,624
# │    └─ReLU: 2-17                        --
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Sequential: 1-10                       --
# │    └─Dropout: 2-18                     --
# │    └─Linear: 2-19                      131,136
# │    └─Tanh: 2-20                        --
# =================================================================
# Total params: 12,609,664
# Trainable params: 4,066,368
# Non-trainable params: 8,543,296
# =================================================================

# %%
torchinfo.summary( rgb_cnn)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            (9,408)
# ├─BatchNorm2d: 1-2                       (128)
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─Bottleneck: 2-1                   --
# │    │    └─Conv2d: 3-1                  (4,096)
# │    │    └─BatchNorm2d: 3-2             (128)
# │    │    └─Conv2d: 3-3                  (36,864)
# │    │    └─BatchNorm2d: 3-4             (128)
# │    │    └─Conv2d: 3-5                  (16,384)
# │    │    └─BatchNorm2d: 3-6             (512)
# │    │    └─ReLU: 3-7                    --
# │    │    └─Sequential: 3-8              (16,896)
# │    └─Bottleneck: 2-2                   --
# │    │    └─Conv2d: 3-9                  (16,384)
# │    │    └─BatchNorm2d: 3-10            (128)
# │    │    └─Conv2d: 3-11                 (36,864)
# │    │    └─BatchNorm2d: 3-12            (128)
# │    │    └─Conv2d: 3-13                 (16,384)
# │    │    └─BatchNorm2d: 3-14            (512)
# │    │    └─ReLU: 3-15                   --
# │    └─Bottleneck: 2-3                   --
# │    │    └─Conv2d: 3-16                 (16,384)
# │    │    └─BatchNorm2d: 3-17            (128)
# │    │    └─Conv2d: 3-18                 (36,864)
# │    │    └─BatchNorm2d: 3-19            (128)
# │    │    └─Conv2d: 3-20                 (16,384)
# │    │    └─BatchNorm2d: 3-21            (512)
# │    │    └─ReLU: 3-22                   --
# ├─Sequential: 1-6                        --
# │    └─Bottleneck: 2-4                   --
# │    │    └─Conv2d: 3-23                 (32,768)
# │    │    └─BatchNorm2d: 3-24            (256)
# │    │    └─Conv2d: 3-25                 (147,456)
# │    │    └─BatchNorm2d: 3-26            (256)
# │    │    └─Conv2d: 3-27                 (65,536)
# │    │    └─BatchNorm2d: 3-28            (1,024)
# │    │    └─ReLU: 3-29                   --
# │    │    └─Sequential: 3-30             (132,096)
# │    └─Bottleneck: 2-5                   --
# │    │    └─Conv2d: 3-31                 (65,536)
# │    │    └─BatchNorm2d: 3-32            (256)
# │    │    └─Conv2d: 3-33                 (147,456)
# │    │    └─BatchNorm2d: 3-34            (256)
# │    │    └─Conv2d: 3-35                 (65,536)
# │    │    └─BatchNorm2d: 3-36            (1,024)
# │    │    └─ReLU: 3-37                   --
# │    └─Bottleneck: 2-6                   --
# │    │    └─Conv2d: 3-38                 (65,536)
# │    │    └─BatchNorm2d: 3-39            (256)
# │    │    └─Conv2d: 3-40                 (147,456)
# │    │    └─BatchNorm2d: 3-41            (256)
# │    │    └─Conv2d: 3-42                 (65,536)
# │    │    └─BatchNorm2d: 3-43            (1,024)
# │    │    └─ReLU: 3-44                   --
# │    └─Bottleneck: 2-7                   --
# │    │    └─Conv2d: 3-45                 (65,536)
# │    │    └─BatchNorm2d: 3-46            (256)
# │    │    └─Conv2d: 3-47                 (147,456)
# │    │    └─BatchNorm2d: 3-48            (256)
# │    │    └─Conv2d: 3-49                 (65,536)
# │    │    └─BatchNorm2d: 3-50            (1,024)
# │    │    └─ReLU: 3-51                   --
# ├─Sequential: 1-7                        --
# │    └─Bottleneck: 2-8                   --
# │    │    └─Conv2d: 3-52                 (131,072)
# │    │    └─BatchNorm2d: 3-53            (512)
# │    │    └─Conv2d: 3-54                 (589,824)
# │    │    └─BatchNorm2d: 3-55            (512)
# │    │    └─Conv2d: 3-56                 (262,144)
# │    │    └─BatchNorm2d: 3-57            (2,048)
# │    │    └─ReLU: 3-58                   --
# │    │    └─Sequential: 3-59             (526,336)
# │    └─Bottleneck: 2-9                   --
# │    │    └─Conv2d: 3-60                 (262,144)
# │    │    └─BatchNorm2d: 3-61            (512)
# │    │    └─Conv2d: 3-62                 (589,824)
# │    │    └─BatchNorm2d: 3-63            (512)
# │    │    └─Conv2d: 3-64                 (262,144)
# │    │    └─BatchNorm2d: 3-65            (2,048)
# │    │    └─ReLU: 3-66                   --
# │    └─Bottleneck: 2-10                  --
# │    │    └─Conv2d: 3-67                 (262,144)
# │    │    └─BatchNorm2d: 3-68            (512)
# │    │    └─Conv2d: 3-69                 (589,824)
# │    │    └─BatchNorm2d: 3-70            (512)
# │    │    └─Conv2d: 3-71                 (262,144)
# │    │    └─BatchNorm2d: 3-72            (2,048)
# │    │    └─ReLU: 3-73                   --
# │    └─Bottleneck: 2-11                  --
# │    │    └─Conv2d: 3-74                 (262,144)
# │    │    └─BatchNorm2d: 3-75            (512)
# │    │    └─Conv2d: 3-76                 (589,824)
# │    │    └─BatchNorm2d: 3-77            (512)
# │    │    └─Conv2d: 3-78                 (262,144)
# │    │    └─BatchNorm2d: 3-79            (2,048)
# │    │    └─ReLU: 3-80                   --
# │    └─Bottleneck: 2-12                  --
# │    │    └─Conv2d: 3-81                 (262,144)
# │    │    └─BatchNorm2d: 3-82            (512)
# │    │    └─Conv2d: 3-83                 (589,824)
# │    │    └─BatchNorm2d: 3-84            (512)
# │    │    └─Conv2d: 3-85                 (262,144)
# │    │    └─BatchNorm2d: 3-86            (2,048)
# │    │    └─ReLU: 3-87                   --
# │    └─Bottleneck: 2-13                  --
# │    │    └─Conv2d: 3-88                 (262,144)
# │    │    └─BatchNorm2d: 3-89            (512)
# │    │    └─Conv2d: 3-90                 (589,824)
# │    │    └─BatchNorm2d: 3-91            (512)
# │    │    └─Conv2d: 3-92                 (262,144)
# │    │    └─BatchNorm2d: 3-93            (2,048)
# │    │    └─ReLU: 3-94                   --
# ├─Sequential: 1-8                        --
# │    └─Conv2d: 2-14                      524,800
# │    └─Conv2d: 2-15                      2,359,808
# │    └─Conv2d: 2-16                      1,050,624
# │    └─ReLU: 2-17                        --
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Sequential: 1-10                       --
# │    └─Dropout: 2-18                     --
# │    └─Linear: 2-19                      131,136
# │    └─Tanh: 2-20                        --
# =================================================================
# Total params: 12,609,664
# Trainable params: 4,066,368
# Non-trainable params: 8,543,296
# =================================================================

# %%
torchinfo.summary(final_pose_estimator)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Sequential                               --
# ├─Linear: 1-1                            774
# =================================================================
# Total params: 774
# Trainable params: 774
# Non-trainable params: 0
# =================================================================

# %%
#depth_cnn.load_state_dict(torch.load("dual_resnet50posev2_depth_38pep.pth"))
#rgb_cnn.load_state_dict(torch.load("dual_resnet50posev2_rgb_38pep.pth"))
#final_pose_estimator.load_state_dict(torch.load("dual_final_pose_estimatorv2_38pep.pth"))

#depth_cnn.eval()
#rgb_cnn.eval()
#final_pose_estimator.eval()
# Out:
# <All keys matched successfully>

# %%
lossFunc = nn.MSELoss()
optimizer = optim.Adam(list(depth_cnn.parameters()) + list(rgb_cnn.parameters()) + list(final_pose_estimator.parameters()), lr=0.00001)

# %%
# ensure eval mode to turn of batch norm as this might hurt regression performance
#depth_cnn.eval()
#rgb_cnn.eval()
#final_pose_estimator.eval()

depth_cnn.train()
rgb_cnn.train()
final_pose_estimator.train()


for epoch in range(5):
    inner_loop_counter = 0
    for [rgb_inputs, labels], [depth_inputs, labels_2] in zip(rgb_train_dataloader, depth_train_dataloader):
        print([torch.isnan(rgb_inputs).any(), torch.isnan(depth_inputs).any()])

        if not torch.isnan(depth_inputs).any().item():
            acc = None
            # forward, backward, and then weight update
            y_pred = paralle_cnn(rgb_inputs.float().cuda(), depth_inputs.float().cuda())
            #y_pred = paralle_cnn(rgb_inputs.float(), depth_inputs.float())
            #print(f"raw output {y_pred}")
            loss = lossFunc(y_pred, labels.float().cuda())
            #loss = lossFunc(y_pred, labels.float())

            print(f" test labels {torch.sum(labels - labels_2)}")
            print(loss.item())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            print(f"training loop complete inner loop {inner_loop_counter}")
            inner_loop_counter += 1
        else:
            print('loop skiped due to bad input')
        #test_pred = model((test_input.float()).type(torch.cuda.FloatTensor))
        #acc += torch.mean(torch.abs(y_pred - labels.type(torch.cuda.FloatTensor)),dim = 0)
        #print(f"acc {acc}")
    print(f"epoch {epoch}")
# Out:
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.523903731344035e-06
# training loop complete inner loop 0
# [tensor(False), tensor(False)]
#  test labels 0.0
# 7.354274202953093e-06
# training loop complete inner loop 1
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2410654310078826e-06
# training loop complete inner loop 2
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.424403869052185e-06
# training loop complete inner loop 3
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3877613532240503e-06
# training loop complete inner loop 4
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.978738732257625e-06
# training loop complete inner loop 5
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.457068260104279e-06
# training loop complete inner loop 6
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.694888391692075e-06
# training loop complete inner loop 7
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1786194085725583e-06
# training loop complete inner loop 8
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2736448954674415e-06
# training loop complete inner loop 9
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2217307105165673e-06
# training loop complete inner loop 10
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7928836061619222e-06
# training loop complete inner loop 11
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8929962354595773e-06
# training loop complete inner loop 12
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.694079512366443e-06
# training loop complete inner loop 13
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2026055123424158e-06
# training loop complete inner loop 14
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.130363777221646e-06
# training loop complete inner loop 15
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.175584424752742e-06
# training loop complete inner loop 16
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6910900032817153e-06
# training loop complete inner loop 17
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.067063400725601e-06
# training loop complete inner loop 18
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9982797968841624e-06
# training loop complete inner loop 19
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5177858990209643e-06
# training loop complete inner loop 20
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3437721665686695e-06
# training loop complete inner loop 21
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7425255666457815e-06
# training loop complete inner loop 22
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.925872078980319e-06
# training loop complete inner loop 23
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4861138829000993e-06
# training loop complete inner loop 24
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2949781143543078e-06
# training loop complete inner loop 25
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.553219019318931e-06
# training loop complete inner loop 26
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.506409373381757e-06
# training loop complete inner loop 27
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.840027718775673e-06
# training loop complete inner loop 28
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.850181201414671e-06
# training loop complete inner loop 29
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.846091087529203e-06
# training loop complete inner loop 30
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.576329163479386e-06
# training loop complete inner loop 31
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.7298826757469214e-06
# training loop complete inner loop 32
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0502385470754234e-06
# training loop complete inner loop 33
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.736500164246536e-06
# training loop complete inner loop 34
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.881522505049361e-06
# training loop complete inner loop 35
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.531531885731965e-06
# training loop complete inner loop 36
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0911378416931257e-06
# training loop complete inner loop 37
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.917894678626908e-06
# training loop complete inner loop 38
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5181370801874436e-06
# training loop complete inner loop 39
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.880290367102134e-06
# training loop complete inner loop 40
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.320368705317378e-06
# training loop complete inner loop 41
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.065252596774371e-06
# training loop complete inner loop 42
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.608074621297419e-06
# training loop complete inner loop 43
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.293180270702578e-06
# training loop complete inner loop 44
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.780131580948364e-06
# training loop complete inner loop 45
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7493986181070795e-06
# training loop complete inner loop 46
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6643806450010743e-06
# training loop complete inner loop 47
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7594639959716005e-06
# training loop complete inner loop 48
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.962977982359007e-06
# training loop complete inner loop 49
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.1511621020617895e-06
# training loop complete inner loop 50
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7066312213719357e-06
# training loop complete inner loop 51
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.710935743583832e-06
# training loop complete inner loop 52
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8780923457816243e-06
# training loop complete inner loop 53
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.016349521407392e-06
# training loop complete inner loop 54
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.72482645616401e-06
# training loop complete inner loop 55
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.31608634951408e-06
# training loop complete inner loop 56
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3024723506969167e-06
# training loop complete inner loop 57
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4136992326239124e-06
# training loop complete inner loop 58
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.779286660370417e-06
# training loop complete inner loop 59
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.473596734693274e-06
# training loop complete inner loop 60
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.145411367062479e-06
# training loop complete inner loop 61
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.1161756598739885e-06
# training loop complete inner loop 62
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.526437805907335e-06
# training loop complete inner loop 63
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7298387976770755e-06
# training loop complete inner loop 64
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.049324848485412e-06
# training loop complete inner loop 65
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1063243568496546e-06
# training loop complete inner loop 66
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3636603145860136e-06
# training loop complete inner loop 67
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.218638423481025e-06
# training loop complete inner loop 68
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.432446985447314e-06
# training loop complete inner loop 69
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0203634651115863e-06
# training loop complete inner loop 70
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6423256258567562e-06
# training loop complete inner loop 71
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.576937731646467e-06
# training loop complete inner loop 72
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.658979833038757e-06
# training loop complete inner loop 73
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.07171807839768e-06
# training loop complete inner loop 74
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.0306422306457534e-06
# training loop complete inner loop 75
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4148611121054273e-06
# training loop complete inner loop 76
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2687272576149553e-06
# training loop complete inner loop 77
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.138815711485222e-06
# training loop complete inner loop 78
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.5587670431123115e-06
# training loop complete inner loop 79
# [tensor(False), tensor(False)]
#  test labels 0.0
# 6.930249583092518e-06
# training loop complete inner loop 80
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.331856300472282e-06
# training loop complete inner loop 81
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4317473616974894e-06
# training loop complete inner loop 82
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.080822352785617e-06
# training loop complete inner loop 83
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.636423000192735e-06
# training loop complete inner loop 84
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.8401848289358895e-06
# training loop complete inner loop 85
# [tensor(False), tensor(False)]
#  test labels 0.0
# 7.953063686727546e-06
# training loop complete inner loop 86
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1800050237507094e-06
# training loop complete inner loop 87
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.55281338468194e-06
# training loop complete inner loop 88
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.34505750995595e-06
# training loop complete inner loop 89
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.857579147530487e-06
# training loop complete inner loop 90
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.241467195242876e-06
# training loop complete inner loop 91
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.4672378862742335e-06
# training loop complete inner loop 92
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.804166565008927e-06
# training loop complete inner loop 93
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5907910387322772e-06
# training loop complete inner loop 94
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.033491909969598e-06
# training loop complete inner loop 95
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.622549800435081e-06
# training loop complete inner loop 96
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.497745521803154e-06
# training loop complete inner loop 97
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.8239822970354e-06
# training loop complete inner loop 98
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.555919081714819e-06
# training loop complete inner loop 99
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.072794925174094e-06
# training loop complete inner loop 100
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4135706553352065e-06
# training loop complete inner loop 101
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2546114450960886e-06
# training loop complete inner loop 102
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5474200811004266e-06
# training loop complete inner loop 103
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0508715553878574e-06
# training loop complete inner loop 104
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.7486391849815845e-06
# training loop complete inner loop 105
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5567676402715733e-06
# training loop complete inner loop 106
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.078083070955472e-06
# training loop complete inner loop 107
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.682804506548564e-06
# training loop complete inner loop 108
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8614874736376805e-06
# training loop complete inner loop 109
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4932858195825247e-06
# training loop complete inner loop 110
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.729262405409827e-06
# training loop complete inner loop 111
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.959912080768845e-06
# training loop complete inner loop 112
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.517190296202898e-06
# training loop complete inner loop 113
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0255384899646742e-06
# training loop complete inner loop 114
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.807716100505786e-06
# training loop complete inner loop 115
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.871619244615431e-06
# training loop complete inner loop 116
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.162305236197426e-06
# training loop complete inner loop 117
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7701034923666157e-06
# training loop complete inner loop 118
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4932235191954533e-06
# training loop complete inner loop 119
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7591968319029547e-06
# training loop complete inner loop 120
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.218905931134941e-06
# training loop complete inner loop 121
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.605931513244286e-06
# training loop complete inner loop 122
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.915291250043083e-06
# training loop complete inner loop 123
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.042708729277365e-06
# training loop complete inner loop 124
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0630305900558596e-06
# training loop complete inner loop 125
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7939399842580315e-06
# training loop complete inner loop 126
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.352775481995195e-06
# training loop complete inner loop 127
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.750984549493296e-06
# training loop complete inner loop 128
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3741663426335435e-06
# training loop complete inner loop 129
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.693788585223956e-06
# training loop complete inner loop 130
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.248585355526302e-06
# training loop complete inner loop 131
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1811570150021e-06
# training loop complete inner loop 132
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.73266778094694e-06
# training loop complete inner loop 133
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8612166715902276e-06
# training loop complete inner loop 134
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.441712922518491e-06
# training loop complete inner loop 135
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.6350605771294795e-06
# training loop complete inner loop 136
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7240813526295824e-06
# training loop complete inner loop 137
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.142844550689915e-06
# training loop complete inner loop 138
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.308788452864974e-06
# training loop complete inner loop 139
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6352880670165177e-06
# training loop complete inner loop 140
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7790114220115356e-06
# training loop complete inner loop 141
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.155757324042497e-06
# training loop complete inner loop 142
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.860674612747971e-06
# training loop complete inner loop 143
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2187291506270412e-06
# training loop complete inner loop 144
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.395745468675159e-06
# training loop complete inner loop 145
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.091689904977102e-06
# training loop complete inner loop 146
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3816292014089413e-06
# training loop complete inner loop 147
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2896491575229447e-06
# training loop complete inner loop 148
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.8210077946132515e-06
# training loop complete inner loop 149
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.984285285696387e-06
# training loop complete inner loop 150
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4543445508461446e-06
# training loop complete inner loop 151
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.819615474436432e-06
# training loop complete inner loop 152
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3922270884213503e-06
# training loop complete inner loop 153
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.401189931333647e-06
# training loop complete inner loop 154
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.586458776931977e-06
# training loop complete inner loop 155
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9551519017113606e-06
# training loop complete inner loop 156
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2454827305627987e-06
# training loop complete inner loop 157
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.033965301961871e-06
# training loop complete inner loop 158
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.628655238368083e-06
# training loop complete inner loop 159
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.848317762982333e-06
# training loop complete inner loop 160
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.464500084897736e-06
# training loop complete inner loop 161
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9969784261775203e-06
# training loop complete inner loop 162
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.606394218673813e-06
# training loop complete inner loop 163
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0028977562324144e-06
# training loop complete inner loop 164
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0020626127225114e-06
# training loop complete inner loop 165
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.700023969737231e-06
# training loop complete inner loop 166
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0127891932352213e-06
# training loop complete inner loop 167
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.401884557912126e-06
# training loop complete inner loop 168
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.650409214766114e-06
# training loop complete inner loop 169
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.872559662137064e-06
# training loop complete inner loop 170
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5886719160771463e-06
# training loop complete inner loop 171
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.411788727840758e-06
# training loop complete inner loop 172
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5120574466418475e-06
# training loop complete inner loop 173
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3071922896633623e-06
# training loop complete inner loop 174
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3000510484271217e-06
# training loop complete inner loop 175
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.613736569401226e-06
# training loop complete inner loop 176
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5593024020054145e-06
# training loop complete inner loop 177
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.599459094199119e-06
# training loop complete inner loop 178
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4229454993474064e-06
# training loop complete inner loop 179
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8744507289957255e-06
# training loop complete inner loop 180
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3207203412312083e-06
# training loop complete inner loop 181
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4307367968722247e-06
# training loop complete inner loop 182
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.529146513552405e-06
# training loop complete inner loop 183
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3154801712953486e-06
# training loop complete inner loop 184
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6476859602553304e-06
# training loop complete inner loop 185
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.413684342172928e-06
# training loop complete inner loop 186
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.18587149195082e-06
# training loop complete inner loop 187
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9863056170142954e-06
# training loop complete inner loop 188
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6811217139766086e-06
# training loop complete inner loop 189
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4302798919961788e-06
# training loop complete inner loop 190
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4383024285489228e-06
# training loop complete inner loop 191
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.9970532270672265e-06
# training loop complete inner loop 192
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.288243194925599e-06
# training loop complete inner loop 193
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.265844159410335e-06
# training loop complete inner loop 194
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3461170712835155e-06
# training loop complete inner loop 195
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0618326743715443e-06
# training loop complete inner loop 196
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.261201866029296e-06
# training loop complete inner loop 197
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.572851710487157e-06
# training loop complete inner loop 198
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.52659447141923e-06
# training loop complete inner loop 199
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.459491724948748e-06
# training loop complete inner loop 200
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.069948888878571e-06
# training loop complete inner loop 201
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.800767444772646e-06
# training loop complete inner loop 202
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.699763965414604e-06
# training loop complete inner loop 203
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7979140213574283e-06
# training loop complete inner loop 204
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.654211923276307e-06
# training loop complete inner loop 205
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9114972928946372e-06
# training loop complete inner loop 206
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0680562304041814e-06
# training loop complete inner loop 207
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.353139047452714e-06
# training loop complete inner loop 208
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.949705387640279e-06
# training loop complete inner loop 209
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.444493358983891e-06
# training loop complete inner loop 210
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.835888037428958e-06
# training loop complete inner loop 211
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1822274902660865e-06
# training loop complete inner loop 212
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5010939427593257e-06
# training loop complete inner loop 213
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.641157829610165e-06
# training loop complete inner loop 214
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.530336693482241e-06
# training loop complete inner loop 215
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2109880976349814e-06
# training loop complete inner loop 216
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5798846056422917e-06
# training loop complete inner loop 217
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3656177745579043e-06
# training loop complete inner loop 218
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.333527613198385e-06
# training loop complete inner loop 219
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.147262982063694e-06
# training loop complete inner loop 220
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.5458018576027825e-06
# training loop complete inner loop 221
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0770104331168113e-06
# training loop complete inner loop 222
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.497148216207279e-06
# training loop complete inner loop 223
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3736541809048504e-06
# training loop complete inner loop 224
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.292612175049726e-06
# training loop complete inner loop 225
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6401197576196864e-06
# training loop complete inner loop 226
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.553926828521071e-06
# training loop complete inner loop 227
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.789803602354368e-06
# training loop complete inner loop 228
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8462122827477288e-06
# training loop complete inner loop 229
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5178825328330277e-06
# training loop complete inner loop 230
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.284908189016278e-06
# training loop complete inner loop 231
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.138468739256496e-06
# training loop complete inner loop 232
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.237409484630916e-06
# training loop complete inner loop 233
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.182351747454959e-06
# training loop complete inner loop 234
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1817154447489884e-06
# training loop complete inner loop 235
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6102837839280255e-06
# training loop complete inner loop 236
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.49226263804303e-06
# training loop complete inner loop 237
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.300963155401405e-06
# training loop complete inner loop 238
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.19150410380098e-06
# training loop complete inner loop 239
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.292276910040528e-06
# training loop complete inner loop 240
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7895164294022834e-06
# training loop complete inner loop 241
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3384827727568336e-06
# training loop complete inner loop 242
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.518573748806375e-06
# training loop complete inner loop 243
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.940705937566236e-06
# training loop complete inner loop 244
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.808949936181307e-06
# training loop complete inner loop 245
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6142744193057297e-06
# training loop complete inner loop 246
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.752062300714897e-06
# training loop complete inner loop 247
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.599699655547738e-06
# training loop complete inner loop 248
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0791229619353544e-06
# training loop complete inner loop 249
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1742001738166437e-06
# training loop complete inner loop 250
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.219585546001326e-06
# training loop complete inner loop 251
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.743878434965154e-06
# training loop complete inner loop 252
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.293036909075454e-06
# training loop complete inner loop 253
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2763769013399724e-06
# training loop complete inner loop 254
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2424647997686407e-06
# training loop complete inner loop 255
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.934099706588313e-06
# training loop complete inner loop 256
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.218314527155599e-06
# training loop complete inner loop 257
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.6719496822333895e-06
# training loop complete inner loop 258
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4161421353928745e-06
# training loop complete inner loop 259
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1651678707712563e-06
# training loop complete inner loop 260
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.51346693605592e-06
# training loop complete inner loop 261
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.790616341982968e-06
# training loop complete inner loop 262
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.936923687637318e-06
# training loop complete inner loop 263
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.565521405515028e-06
# training loop complete inner loop 264
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.276974894106388e-06
# training loop complete inner loop 265
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.151644705212675e-06
# training loop complete inner loop 266
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.415720129851252e-06
# training loop complete inner loop 267
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.56082079836051e-06
# training loop complete inner loop 268
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.670649898092961e-06
# training loop complete inner loop 269
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.632078344002366e-06
# training loop complete inner loop 270
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.586905106407357e-06
# training loop complete inner loop 271
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3821539798518643e-06
# training loop complete inner loop 272
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9513798835978378e-06
# training loop complete inner loop 273
# [tensor(False), tensor(False)]
#  test labels 0.0
# 6.575577572220936e-06
# training loop complete inner loop 274
# [tensor(False), tensor(False)]
#  test labels 0.0
# 6.057986865926068e-06
# training loop complete inner loop 275
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.742105375044048e-06
# training loop complete inner loop 276
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.899990704463562e-06
# training loop complete inner loop 277
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8222536911926e-06
# training loop complete inner loop 278
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.815839252434671e-06
# training loop complete inner loop 279
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.171735210751649e-06
# training loop complete inner loop 280
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5176049095753115e-06
# training loop complete inner loop 281
# epoch 0
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.1881148717948236e-06
# training loop complete inner loop 0
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.3870913941645995e-06
# training loop complete inner loop 1
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2886196095205378e-06
# training loop complete inner loop 2
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2325446025206475e-06
# training loop complete inner loop 3
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.7686580728623085e-06
# training loop complete inner loop 4
# [tensor(False), tensor(False)]
#  test labels 0.0
# 6.268503057071939e-06
# training loop complete inner loop 5
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.296116458135657e-06
# training loop complete inner loop 6
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.3383823797048535e-06
# training loop complete inner loop 7
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7510047857504105e-06
# training loop complete inner loop 8
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0503622383548645e-06
# training loop complete inner loop 9
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.440692464413587e-06
# training loop complete inner loop 10
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.069114882237045e-06
# training loop complete inner loop 11
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.395676569401985e-06
# training loop complete inner loop 12
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.953698978875764e-06
# training loop complete inner loop 13
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.199147158738924e-06
# training loop complete inner loop 14
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9149883883073926e-06
# training loop complete inner loop 15
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7718449473468354e-06
# training loop complete inner loop 16
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.316951162763871e-06
# training loop complete inner loop 17
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.344712917576544e-06
# training loop complete inner loop 18
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.51823495698045e-06
# training loop complete inner loop 19
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.519772462823312e-06
# training loop complete inner loop 20
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3909237825137097e-06
# training loop complete inner loop 21
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5715316951391287e-06
# training loop complete inner loop 22
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.229487331031123e-06
# training loop complete inner loop 23
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.487470166874118e-06
# training loop complete inner loop 24
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.26261465488642e-06
# training loop complete inner loop 25
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.272370920763933e-06
# training loop complete inner loop 26
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1019480957183987e-06
# training loop complete inner loop 27
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2291085315373493e-06
# training loop complete inner loop 28
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8796621336368844e-06
# training loop complete inner loop 29
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.534556981321657e-06
# training loop complete inner loop 30
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1480390134674963e-06
# training loop complete inner loop 31
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.3559539335547015e-06
# training loop complete inner loop 32
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6259857552067842e-06
# training loop complete inner loop 33
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.495615035513765e-06
# training loop complete inner loop 34
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.186454821639927e-06
# training loop complete inner loop 35
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1395466066896915e-06
# training loop complete inner loop 36
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5687460240296787e-06
# training loop complete inner loop 37
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.1607509047025815e-06
# training loop complete inner loop 38
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.328491741034668e-06
# training loop complete inner loop 39
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9841239665984176e-06
# training loop complete inner loop 40
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2863746380608063e-06
# training loop complete inner loop 41
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5196260341763264e-06
# training loop complete inner loop 42
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9525253921747208e-06
# training loop complete inner loop 43
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.031204298371449e-06
# training loop complete inner loop 44
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.344381406757748e-06
# training loop complete inner loop 45
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.406611656624591e-06
# training loop complete inner loop 46
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0045501969434554e-06
# training loop complete inner loop 47
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7318441172828898e-06
# training loop complete inner loop 48
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.816612661466934e-06
# training loop complete inner loop 49
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2479351830261294e-06
# training loop complete inner loop 50
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5902028230339056e-06
# training loop complete inner loop 51
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.769441834971076e-06
# training loop complete inner loop 52
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9096839878329774e-06
# training loop complete inner loop 53
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.020376198037411e-06
# training loop complete inner loop 54
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8081976779503748e-06
# training loop complete inner loop 55
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.261833393888082e-06
# training loop complete inner loop 56
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.851861381714116e-06
# training loop complete inner loop 57
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.145689672441222e-06
# training loop complete inner loop 58
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6996148082835134e-06
# training loop complete inner loop 59
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3812542622181354e-06
# training loop complete inner loop 60
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.845466497092275e-06
# training loop complete inner loop 61
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.088848072569817e-06
# training loop complete inner loop 62
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.576507651814609e-06
# training loop complete inner loop 63
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.8523294279002585e-06
# training loop complete inner loop 64
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.451935754128499e-06
# training loop complete inner loop 65
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.817856284309528e-06
# training loop complete inner loop 66
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7612644518958405e-06
# training loop complete inner loop 67
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.950440714106662e-06
# training loop complete inner loop 68
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.343054570199456e-06
# training loop complete inner loop 69
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.553101578290807e-06
# training loop complete inner loop 70
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.414905793557409e-06
# training loop complete inner loop 71
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0888951439701486e-06
# training loop complete inner loop 72
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4050358408421744e-06
# training loop complete inner loop 73
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.47385355073493e-06
# training loop complete inner loop 74
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.2205178942822386e-06
# training loop complete inner loop 75
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.154864654992707e-06
# training loop complete inner loop 76
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.806542397593148e-06
# training loop complete inner loop 77
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.098744744216674e-06
# training loop complete inner loop 78
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5682288651296403e-06
# training loop complete inner loop 79
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.013924353785114e-06
# training loop complete inner loop 80
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.53609982287162e-06
# training loop complete inner loop 81
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.320383479556767e-06
# training loop complete inner loop 82
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.737789256774704e-06
# training loop complete inner loop 83
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0390281153813703e-06
# training loop complete inner loop 84
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7418977879278827e-06
# training loop complete inner loop 85
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.724184352904558e-06
# training loop complete inner loop 86
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.481527073745383e-06
# training loop complete inner loop 87
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.673363036999945e-06
# training loop complete inner loop 88
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2774769351817667e-06
# training loop complete inner loop 89
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.594662646515644e-06
# training loop complete inner loop 90
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7216929083806463e-06
# training loop complete inner loop 91
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.27240229328163e-06
# training loop complete inner loop 92
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.748256287712138e-06
# training loop complete inner loop 93
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.067163899890147e-06
# training loop complete inner loop 94
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2779948924144264e-06
# training loop complete inner loop 95
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1167687666311394e-06
# training loop complete inner loop 96
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0414325919991825e-06
# training loop complete inner loop 97
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9220370834082132e-06
# training loop complete inner loop 98
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.417983068880858e-06
# training loop complete inner loop 99
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4282045362488134e-06
# training loop complete inner loop 100
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6156793612462934e-06
# training loop complete inner loop 101
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.869812078643008e-06
# training loop complete inner loop 102
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0941992008592933e-06
# training loop complete inner loop 103
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.803238658088958e-06
# training loop complete inner loop 104
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.317540970077971e-06
# training loop complete inner loop 105
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5075215691904305e-06
# training loop complete inner loop 106
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.014957999563194e-06
# training loop complete inner loop 107
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.221667955382145e-06
# training loop complete inner loop 108
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.057815774809569e-06
# training loop complete inner loop 109
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2185487270908197e-06
# training loop complete inner loop 110
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.020154053956503e-06
# training loop complete inner loop 111
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.528644245103351e-06
# training loop complete inner loop 112
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8953741093573626e-06
# training loop complete inner loop 113
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6288089429726824e-06
# training loop complete inner loop 114
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.35480387750431e-06
# training loop complete inner loop 115
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.421016461084946e-06
# training loop complete inner loop 116
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.430737140457495e-06
# training loop complete inner loop 117
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0131420771795092e-06
# training loop complete inner loop 118
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.331667474209098e-06
# training loop complete inner loop 119
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.8633543277246645e-06
# training loop complete inner loop 120
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5217095753760077e-06
# training loop complete inner loop 121
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5297440515714698e-06
# training loop complete inner loop 122
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.227517597930273e-06
# training loop complete inner loop 123
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4827791094139684e-06
# training loop complete inner loop 124
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5339916192024248e-06
# training loop complete inner loop 125
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2793512926000403e-06
# training loop complete inner loop 126
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8068841402273392e-06
# training loop complete inner loop 127
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.158014012820786e-06
# training loop complete inner loop 128
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.596540070953779e-06
# training loop complete inner loop 129
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7123976451548515e-06
# training loop complete inner loop 130
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0506860184686957e-06
# training loop complete inner loop 131
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.83603253592446e-06
# training loop complete inner loop 132
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.168999228364555e-06
# training loop complete inner loop 133
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.251367050121189e-06
# training loop complete inner loop 134
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.644198957568733e-06
# training loop complete inner loop 135
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.391098289284855e-06
# training loop complete inner loop 136
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.153007128275931e-06
# training loop complete inner loop 137
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.916342737080413e-06
# training loop complete inner loop 138
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.548848442529561e-06
# training loop complete inner loop 139
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.904580808011815e-06
# training loop complete inner loop 140
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.193296495534014e-06
# training loop complete inner loop 141
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.520723228371935e-06
# training loop complete inner loop 142
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6011182399088284e-06
# training loop complete inner loop 143
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.868525032477919e-06
# training loop complete inner loop 144
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.56662815445452e-06
# training loop complete inner loop 145
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9102445751050254e-06
# training loop complete inner loop 146
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7000201043847483e-06
# training loop complete inner loop 147
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4723967726458795e-06
# training loop complete inner loop 148
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8033773560309783e-06
# training loop complete inner loop 149
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7471239718579454e-06
# training loop complete inner loop 150
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.158695446676575e-06
# training loop complete inner loop 151
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.180681915182504e-06
# training loop complete inner loop 152
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.7862885215436108e-06
# training loop complete inner loop 153
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2282773645420093e-06
# training loop complete inner loop 154
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.728094386839075e-06
# training loop complete inner loop 155
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2266694941208698e-06
# training loop complete inner loop 156
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0876850612694398e-06
# training loop complete inner loop 157
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.177022790623596e-06
# training loop complete inner loop 158
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3236989363795146e-06
# training loop complete inner loop 159
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1594433949067025e-06
# training loop complete inner loop 160
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.426386345177889e-06
# training loop complete inner loop 161
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1012210709159262e-06
# ...
# training loop complete inner loop 150
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.789869085972896e-06
# training loop complete inner loop 151
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0172232072800398e-06
# training loop complete inner loop 152
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1698222099075792e-06
# training loop complete inner loop 153
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.885438789235195e-06
# training loop complete inner loop 154
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.572043740656227e-06
# training loop complete inner loop 155
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.335227009098162e-06
# training loop complete inner loop 156
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.720980774029158e-06
# training loop complete inner loop 157
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.235512056358857e-06
# training loop complete inner loop 158
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.818840357576846e-06
# training loop complete inner loop 159
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.005320422744262e-06
# training loop complete inner loop 160
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.216431767010363e-06
# training loop complete inner loop 161
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4617660276126117e-06
# training loop complete inner loop 162
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5510657906124834e-06
# training loop complete inner loop 163
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3616801172465784e-06
# training loop complete inner loop 164
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.621795601953636e-06
# training loop complete inner loop 165
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.424659214739222e-06
# training loop complete inner loop 166
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.982188223337289e-06
# training loop complete inner loop 167
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.08666926684964e-06
# training loop complete inner loop 168
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.806114025588613e-06
# training loop complete inner loop 169
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8873037081211805e-06
# training loop complete inner loop 170
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5996745282318443e-06
# training loop complete inner loop 171
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.516702352295397e-06
# training loop complete inner loop 172
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4210121409851126e-06
# training loop complete inner loop 173
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.420674263703404e-06
# training loop complete inner loop 174
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5036486022145255e-06
# training loop complete inner loop 175
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.354153366468381e-06
# training loop complete inner loop 176
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.567315045278519e-06
# training loop complete inner loop 177
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.348292693772237e-06
# training loop complete inner loop 178
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4852105272875633e-06
# training loop complete inner loop 179
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.581518629085622e-06
# training loop complete inner loop 180
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.607747319416376e-06
# training loop complete inner loop 181
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.910793682531221e-06
# training loop complete inner loop 182
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4531404960725922e-06
# training loop complete inner loop 183
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9784532671328634e-06
# training loop complete inner loop 184
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1245954232872464e-06
# training loop complete inner loop 185
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.686779109557392e-06
# training loop complete inner loop 186
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1464848032337613e-06
# training loop complete inner loop 187
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9275538508954924e-06
# training loop complete inner loop 188
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1620239749609027e-06
# training loop complete inner loop 189
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.685285835468676e-06
# training loop complete inner loop 190
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.23634185406263e-06
# training loop complete inner loop 191
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8592835406016093e-06
# training loop complete inner loop 192
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0929080619680462e-06
# training loop complete inner loop 193
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.231467078672722e-06
# training loop complete inner loop 194
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2994959181232844e-06
# training loop complete inner loop 195
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.430975655443035e-06
# training loop complete inner loop 196
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.545770480035571e-06
# training loop complete inner loop 197
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5322343592270045e-06
# training loop complete inner loop 198
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.210205022696755e-06
# training loop complete inner loop 199
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.148065050278092e-06
# training loop complete inner loop 200
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3424686332873534e-06
# training loop complete inner loop 201
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1901390684652142e-06
# training loop complete inner loop 202
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5978343930764822e-06
# training loop complete inner loop 203
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4266711281816242e-06
# training loop complete inner loop 204
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.246487267460907e-06
# training loop complete inner loop 205
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.313852746738121e-06
# training loop complete inner loop 206
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3476145543099847e-06
# training loop complete inner loop 207
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4799300010490697e-06
# training loop complete inner loop 208
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.1908717826590873e-06
# training loop complete inner loop 209
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.102841901636566e-06
# training loop complete inner loop 210
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.458877588651376e-06
# training loop complete inner loop 211
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2203795399254886e-06
# training loop complete inner loop 212
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1456927445105975e-06
# training loop complete inner loop 213
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.0795355339942034e-06
# training loop complete inner loop 214
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.670734713523416e-06
# training loop complete inner loop 215
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.396399506527814e-06
# training loop complete inner loop 216
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7587205952149816e-06
# training loop complete inner loop 217
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1606975881004473e-06
# training loop complete inner loop 218
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.923301624628948e-06
# training loop complete inner loop 219
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.8226090762473177e-06
# training loop complete inner loop 220
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9502880352083594e-06
# training loop complete inner loop 221
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.879308678733651e-06
# training loop complete inner loop 222
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.844076672976371e-06
# training loop complete inner loop 223
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.6212305783701595e-06
# training loop complete inner loop 224
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.371684786339756e-06
# training loop complete inner loop 225
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.547974872868508e-06
# training loop complete inner loop 226
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0444480216829106e-06
# training loop complete inner loop 227
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.6668666325567756e-06
# training loop complete inner loop 228
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.98930126518826e-06
# training loop complete inner loop 229
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.350887482156395e-06
# training loop complete inner loop 230
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9697057470912114e-06
# training loop complete inner loop 231
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.2587605599255767e-06
# training loop complete inner loop 232
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.58771717401396e-06
# training loop complete inner loop 233
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4564507132017752e-06
# training loop complete inner loop 234
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.435372263993486e-06
# training loop complete inner loop 235
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4685045900696423e-06
# training loop complete inner loop 236
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.813515948218992e-06
# training loop complete inner loop 237
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9357680685061496e-06
# training loop complete inner loop 238
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.993463567690924e-06
# training loop complete inner loop 239
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.412114660430234e-06
# training loop complete inner loop 240
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.0665619306091685e-06
# training loop complete inner loop 241
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1800216220290167e-06
# training loop complete inner loop 242
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5696207305591088e-06
# training loop complete inner loop 243
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1022459552332293e-06
# training loop complete inner loop 244
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.71715213987045e-06
# training loop complete inner loop 245
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.1483627935813274e-06
# training loop complete inner loop 246
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.718604941444937e-06
# training loop complete inner loop 247
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.227173237974057e-06
# training loop complete inner loop 248
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5918669709644746e-06
# training loop complete inner loop 249
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3128916382120224e-06
# training loop complete inner loop 250
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.85964040106046e-06
# training loop complete inner loop 251
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.7622355648636585e-06
# training loop complete inner loop 252
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.254594387020916e-06
# training loop complete inner loop 253
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.00536294162157e-06
# training loop complete inner loop 254
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.2180992093344685e-06
# training loop complete inner loop 255
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.9558547137421556e-06
# training loop complete inner loop 256
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.136228770017624e-06
# training loop complete inner loop 257
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.776627181650838e-06
# training loop complete inner loop 258
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.0737995732342824e-06
# training loop complete inner loop 259
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.524322892189957e-06
# training loop complete inner loop 260
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.393823933743988e-06
# training loop complete inner loop 261
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.4424894036201295e-06
# training loop complete inner loop 262
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.7921173568756785e-06
# training loop complete inner loop 263
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.461440089973621e-06
# training loop complete inner loop 264
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.160348908044398e-06
# training loop complete inner loop 265
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.9290636121004354e-06
# training loop complete inner loop 266
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.3978441276995e-06
# training loop complete inner loop 267
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.900327217503218e-06
# training loop complete inner loop 268
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.469127139193006e-06
# training loop complete inner loop 269
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.575519713194808e-06
# training loop complete inner loop 270
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.087220531800995e-06
# training loop complete inner loop 271
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4974618756677955e-06
# training loop complete inner loop 272
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.165149564665626e-06
# training loop complete inner loop 273
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.508298621251015e-06
# training loop complete inner loop 274
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.954630872409325e-06
# training loop complete inner loop 275
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.745220510609215e-06
# training loop complete inner loop 276
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.032591394003248e-06
# training loop complete inner loop 277
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.931412382167764e-06
# training loop complete inner loop 278
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.4804322694981238e-06
# training loop complete inner loop 279
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.379354555159807e-06
# training loop complete inner loop 280
# [tensor(False), tensor(False)]
#  test labels 0.0
# 1.8374093997408636e-06
# training loop complete inner loop 281
# epoch 3
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.484627541183727e-06
# training loop complete inner loop 0
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.5987395676784217e-06
# training loop complete inner loop 1
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.019333457312314e-06
# training loop complete inner loop 2
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3109315609181067e-06
# training loop complete inner loop 3
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.593715064198477e-06
# training loop complete inner loop 4
# [tensor(False), tensor(False)]
#  test labels 0.0
# 2.5450335670029745e-06
# training loop complete inner loop 5
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.143133199046133e-06
# training loop complete inner loop 6
# [tensor(False), tensor(False)]
#  test labels 0.0
# 5.246299224381801e-06
# training loop complete inner loop 7
# [tensor(False), tensor(False)]
#  test labels 0.0
# 4.692445600085193e-06
# training loop complete inner loop 8
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3669027743599145e-06
# training loop complete inner loop 9
# [tensor(False), tensor(False)]
#  test labels 0.0
# 3.3161009014293086e-06
# training loop complete inner loop 10
# [tensor(False), tensor(False)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-bc6391b74a75> in <cell line: 11>()
#      17             acc = None
#      18             # forward, backward, and then weight update
# ---> 19             y_pred = paralle_cnn(rgb_inputs.float().cuda(), depth_inputs.float().cuda())
#      20             #y_pred = paralle_cnn(rgb_inputs.float(), depth_inputs.float())
#      21             #print(f"raw output {y_pred}")
#
# KeyboardInterrupt:

# %% [markdown]
# # New Section

# %%
torch.save(rgb_cnn.state_dict(), "dual_resnet50posev8_rgb_35ep.pth")
torch.save(depth_cnn.state_dict(), "dual_resnet50posev8_depth_35ep.pth")
torch.save(final_pose_estimator.state_dict(), "dual_final_pose_estimatorv8_35ep.pth")

# %%
from google.colab import files

files.download("dual_resnet50posev8_rgb_35ep.pth")
files.download("dual_resnet50posev8_depth_35ep.pth")
files.download("dual_final_pose_estimatorv8_35ep.pth")

# %%
class CustomRGBImageTestDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)[9000:-1]
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path).float()
        label = torch.tensor(self.img_labels.iloc[idx, 1:7])
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label


class CustomDepthImageTestDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)[9000:-1]
        for index, img_label in enumerate(self.img_labels.iloc[:,0]):
            depth_img_label = img_label.replace("rgb_image_", "depth_image_").replace("png", "npy")
            self.img_labels.iloc[index,0] = depth_img_label

        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        np_img = np.load(img_path)
        np_img[np_img > 1] = 0
        image = torch.tensor(np_img).unsqueeze(0)
        image = image.expand(3, *image.shape[1:])
        label = torch.tensor(self.img_labels.iloc[idx, 1:7])
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label


test_dataset_rgb = CustomRGBImageTestDataset(path_to_labels, path_to_rgb_imgs, transform= rgb_transform)
test_dataset_depth = CustomDepthImageTestDataset(path_to_labels, path_to_depth_imgs, transform = depth_transform)

rgb_test_dataloader = DataLoader(test_dataset_rgb, batch_size=1 ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)


depth_test_dataloader = DataLoader(test_dataset_depth, batch_size=1 ,shuffle=False, num_workers=2,pin_memory=True,prefetch_factor=30)

# %%
acc = 0
count = 0

results = []

#depth_cnn.load_state_dict(torch.load("dual_resnet50posev6_depth_40ep.pth"))
#rgb_cnn.load_state_dict(torch.load("dual_resnet50posev6_rgb_40ep.pth"))
#final_pose_estimator.load_state_dict(torch.load("dual_final_pose_estimatorv6_40ep.pth"))

depth_cnn.train()
rgb_cnn.train()
final_pose_estimator.train()

for [rgb_inputs, labels], [depth_inputs, labels_2] in tqdm(zip(rgb_test_dataloader, depth_test_dataloader)):
    with torch.no_grad():  # Ensure no gradients are calculated
        if not torch.isnan(depth_inputs).any().item():
            y_pred = paralle_cnn(rgb_inputs.float().cuda(), depth_inputs.float().cuda())
            buffer = np.zeros(12)
            buffer[0:6] = np.array(labels)
            buffer[6:12] = np.array(y_pred.cpu())
            results.append(buffer)
            #print(torch.cat((y_pred, labels.type(torch.cuda.FloatTensor)), dim = 1 ) * 1000)

            #acc += torch.mean(torch.abs((y_pred - labels.type(torch.cuda.FloatTensor))), dim = 0)
            #count += 1
            #print(labels.size())
            #print(count)
            #print(f"test {acc / count}")
        else:
            print('loop skiped due to bad input')

results = np.array(results)

# Calculate final accuracy after all iterations
#final_acc = acc / count
# Out:
# 999it [00:37, 26.60it/s]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1,3)

for n, ax in enumerate(axs):
    ax.scatter(results[:,n], results[:,n+6], s= 0.7)

plt.show()

# %%
results[0]
# Out:
# array([ 0.03152   , -0.00571   ,  0.0089    ,  0.        ,  0.        ,
#         0.        ,  0.01442401, -0.0073736 ,  0.00758156,  0.00030504,
#         0.00027379, -0.00213458])
